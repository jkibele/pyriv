# %%
# %load "/Users/haleighwright/Desktop/NCEAS/pyriv/notebooks/nb_config.py"
import sys
sys.path.append("/Users/haleighwright/Desktop/NCEAS/pyriv")
sys.path.append("/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages")
import networkx as nx
import numpy as np
import sys
import geopandas as gpd
import seaborn # makes matplotlib graphs look prettier
from shapely.geometry import Point
from multiprocessing import Pool

from pyriv import graph_prep as GraphBuilder
from pyriv import river_graph as RiverGraph
from pyriv import snapping_processor as SnapTool

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # makes matplotlib graphs 2x resolution for retina display

# %% [markdown]
# ## Read in test data (small Alaskan Island)

# %%
test_graph = GraphBuilder.GraphBuilder('../../tests/testdata/test.shp')
# Out:
# Weighting Edges with Distances

# %%
ret = nx.write_gpickle('poop', '../../tests/testdata/poop.gpickle')

# %% [markdown]
# #### there's no indication via networkx that it doesn't work...

# %%
print type(ret)
# Out:
# <type 'NoneType'>

# %%
print ret
# Out:
# None

# %%
test_graph.write_gpickle('../../tests/testdata/test.gpickle')

# %%
testing_readin_nothing = GraphBuilder.GraphBuilder('../../tests/testdata/test.gpickle')
# Out:
# Weighting Edges with Distances

# %%
testing_readin.graph.plot()

# %%
print len(testing_readin.graph.edges())
# Out:
# 2

# %%
test_graph.graph.plot()

# %%
test_graph.write_gpickle('../../tests/testdata/test.gpickle')

# %%
# %pwd
# Out:
# u'/Users/haleighwright/Desktop/NCEAS/pyriv/notebooks/dev'

# %%
type(test_graph)
# Out:
# pyriv.graph_prep.GraphBuilder

# %%
super(type(test_graph.graph),test_graph.graph)
# Out:
# <super: pyriv.river_graph.RiverGraph,
#         <pyriv.river_graph.RiverGraph at 0x1128dcd90>>

# %%
type(test_graph.graph.graph)
# Out:
# dict

# %%
type(test_graph.graph.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-0c7b71862034> in <module>()
# ----> 1 type(test_graph.data)
#
# AttributeError: 'GraphBuilder' object has no attribute 'data'

# %%
abc = nx.DiGraph(test_graph.graph)

# %%
type(abc)
# Out:
# networkx.classes.digraph.DiGraph

# %%
RiverGraph.RiverGraph(abc).graph.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-03fbbbba2c33> in <module>()
# ----> 1 RiverGraph.RiverGraph(abc).graph.plot()
#
# /Users/haleighwright/Desktop/NCEAS/pyriv/pyriv/river_graph.pyc in __init__(self, coastline_shp, *args, **kwargs)
#      63         #if you have problems with typing, rememeber self.as_super
#      64         #magic word here
# ---> 65         self.coastline, self.crs = get_coastline_geom(coastline_shp)
#      66         self._river_mouths_cache = None
#      67         self._inland_deadends_cache = None
#
# /Users/haleighwright/Desktop/NCEAS/pyriv/pyriv/river_graph.pyc in get_coastline_geom(shape_fn)
#      47     """
#      48     if shape_fn:
# ---> 49         cldf = gpd.read_file(shape_fn)
#      50         return cldf.unary_union, cldf.crs
#      51     else:
#
# ...
